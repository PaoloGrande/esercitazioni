# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
# 'Copia di Un benvenuto a Colaboratory'	 Esercitazione01.ipynb	 IMG-4615.JPG

# %%
#metodo per visualizzare file dentro google drive
from IPython.display import Image
Image('IMG-4615.JPG',width=400)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#utilizzo metodo per visualizzare file dentro google drive diverse immagini web

#link = 'https://www.my-personaltrainer.it/2021/04/13/alimentazione-gatto_900x760.jpeg'
#link = 'https://gattissimi.com/wp-content/uploads/2015/12/maxresdefault-22-1.jpg'
link = 'https://i.pinimg.com/originals/c0/c2/8d/c0c28d6f9fe6f0f0d5170220b052319b.jpg'

Image(link,width=500)

# %%
# ESERCIZIO

X = float(input("inserisci valore di X: "))
Y = float(input("inserisci valore di Y: "))

if X < Y:
  print("statement_a")
  if X > Y:
    print("statement_b")
  else:
    print("statement_C")
# Out:
# inserisci valore di X: 0
# inserisci valore di Y: -2
# statement_b
