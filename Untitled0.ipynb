# %%
import pandas as pd

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/tips_complete.csv
# Out:
# --2022-03-18 13:07:37--  https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/tips_complete.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.148.138
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.148.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18752 (18K) [text/csv]
# Saving to: ‘tips_complete.csv’
#
# tips_complete.csv   100%[===================>]  18.31K  --.-KB/s    in 0.1s
#
# 2022-03-18 13:07:37 (145 KB/s) - ‘tips_complete.csv’ saved [18752/18752]

# %%
#!mkdir test
df = pd.read_csv('test/tips_complete.csv')
