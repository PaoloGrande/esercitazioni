# %% [markdown]
# Funzioni

# %%
def sommaduenum(x,y):
  ''' somma delle variabili '''
  ris = x + y
  return ris

# %%
somma = sommaduenum(-150, 100)
somma
# Out:
# -50

# %%
def posneg(x):
  if x<0:
    return('il numero è negativo')
  elif x==0:
    return('inserito 0, cambia numero')
  else:
    return('il numero è positivo')

# %%
x = float(input('inserire un numero'))

if x<0:
  print('il numero è negativo')
elif x==0:
  print('inserito 0, cambia numero')
else:
  print('il numero è positivo')
# Out:
# inserire un numero-6
# il numero è negativo

# %%
def paridispari(x): #classifica il numero inserito come pari o dispari
resto=x % 2
  if resto == 0:
    return 'numero pari'
  else:
    return 'numero dispari'
  
x = int(input('inserire un numero: '))
paridispari(x)
# Out:
# inserire un numero: -5
# 'numero dispari'

# %%
# %%writefile formulario.py

def areatriangolo(b,h):     #calcola l'area di un triangolo dati base e altezza
  areat = b*h/2
  return 'Area Triangolo =', areat
# Out:
# Overwriting formulario.py

# %%
from formulario import areatriangolo as at
at(4,7)
# Out:
# ('Area Triangolo =', 14.0)

# %%
# %%writefile formulario.py

def perimetrotriang(l1,l2,l3):  #calcola il perimetro di un triangolo dai i lati
  perimt=l1+l2+l3
  return 'Perimetro Triangolo = ', perimt

def areatriangolo(b,h):     #calcola l'area di un triangolo dati base e altezza
  areat = b*h/2
  return 'Area Triangolo =', areat
# Out:
# Writing formulario.py

# %%
from formulario import perimetrotriang as pt
from formulario import areatriangolo as at


pt(3,4,5), at(6,4)
# Out:
# (('Perimetro Triangolo = ', 12), ('Area Triangolo =', 12.0))

# %%
cd /content/drive/MyDrive/Colab Notebooks/esercitazioni
# Out:
# /content/drive/MyDrive/Colab Notebooks/esercitazioni

# %%
ls
# Out:
# 01_intro.ipynb         IMG-4615.JPG          README.md
# Esercitazione03.ipynb  Markdown_Colab.ipynb

# %%
# %matplotlib inline    #solo per ottimizzare visualizzazione su notebook
# Out:
# UsageError: unrecognized arguments: #solo per ottimizzare visualizzazione su notebook

# %%
import matplotlib.pyplot as plt

import numpy as np
from numpy.random import rand

# %%
x = rand(100)
y = rand(100)

plt.scatter(x,y)
plt.show()

# %%
x==y
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
y.ndim  #quante dimensioni
# Out:
# 1

# %%
x = rand(100)
print(x)
# Out:
# [0.02087948 0.87536301 0.96992962 0.12354733 0.35743671 0.51251756
#  0.93583169 0.60803963 0.28412953 0.50974023 0.59922297 0.78551273
#  0.35381236 0.23486154 0.75836475 0.35763086 0.20703043 0.40916324
#  0.36421232 0.34080758 0.7379055  0.0274466  0.12041525 0.16960066
#  0.07111352 0.83043606 0.2221722  0.66643481 0.76568445 0.88217611
#  0.2230413  0.27860028 0.3686282  0.2016134  0.58804915 0.52009338
#  0.19494024 0.67403463 0.773729   0.58314179 0.80823201 0.39144355
#  0.37006471 0.08275299 0.37415125 0.50312409 0.36516372 0.04286073
#  0.66837785 0.68028189 0.80093311 0.54998722 0.34417357 0.26794699
#  0.82523775 0.0562271  0.85690341 0.72987302 0.91350877 0.83526641
#  0.57707946 0.60242216 0.98370425 0.91132366 0.9018217  0.25677395
#  0.65571755 0.9110989  0.10603881 0.19597333 0.76781636 0.96337283
#  0.49841002 0.15267354 0.52321916 0.95287572 0.9537745  0.65720664
#  0.50770183 0.56224283 0.28652717 0.85851862 0.34090398 0.8737978
# ...

# %%
x = rand(1000)
y = rand(1000)

plt.scatter(x,y,color="purple")
plt.show()

# %%
plt.plot([10,20,30,40], '--r')  #crea il grafico
plt.ylabel('paperino y')        #comandi vari per formattazione e descrizioni
plt.xlabel('paperino x')
plt.title('titolo grafico')
#plt.show()                     #serve quando non si usa notebook come Colab
# Out:
# Text(0.5, 1.0, 'titolo grafico')
